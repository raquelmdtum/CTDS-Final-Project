# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
import plotly.io as pio
import seaborn as sns

# %%
products = pd.read_csv('data/skincare.csv')

# %%
products.columns
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'variation_desc', 'ingredients', 'price_usd', 'value_price_usd',
#        'sale_price_usd', 'limited_edition', 'new', 'online_only',
#        'out_of_stock', 'sephora_exclusive', 'highlights', 'primary_category',
#        'secondary_category', 'tertiary_category', 'child_count',
#        'child_max_price', 'child_min_price'],
#       dtype='object')

# %%
products.head(2)
# Out:
#   product_id                          product_name  brand_id brand_name  \
# 0    P439055  GENIUS Sleeping Collagen Moisturizer      6018   Algenist
# 1    P421277          GENIUS Liquid Collagen Serum      6018   Algenist
#
#    loves_count  rating  reviews           size variation_type variation_value  \
# 0        33910  4.5413   1321.0    2 oz/ 60 mL           Size     2 oz/ 60 mL
# 1        67870  4.0259   1159.0  1 oz  / 30 mL           Size   1 oz  / 30 mL
#
#    ... online_only out_of_stock  sephora_exclusive  \
# 0  ...           0            0                  1
# 1  ...           0            0                  1
#
#                                           highlights  primary_category  \
# 0  Vegan, Loss of firmness, Collagen, Hypoallerge...          Skincare
# 1  Vegan, Loss of firmness, Collagen, Hypoallerge...          Skincare
#
#    secondary_category  tertiary_category  child_count  child_max_price  \
# ...

# %%
def counts(column, column_name, top_10_df = True, top_10_plots = True):

    count = products[column].value_counts()
    percentage = products[column].value_counts(normalize=True)*100

    df = pd.DataFrame({column_name:count.index,'Counts':count.values,'Percent':np.round(percentage.values,2)})

    if top_10_df == True:
        print(df[:10])
    
    if top_10_plots == True:
        plt.figure(figsize=(8,4))
        sns.barplot(df[:10], x=column_name, y="Counts")
        plt.xticks(rotation=90)
        plt.ylabel('Count')
        plt.title(f'Top 10 Occuring {column_name}s')
        plt.show()

    return

# %%
counts('brand_name', 'Brand')
# Out:
#                 Brand  Counts  Percent
# 0  SEPHORA COLLECTION      62     3.22
# 1               fresh      46     2.39
# 2        The Ordinary      43     2.23
# 3  Kiehl's Since 1851      41     2.13
# 4              Tatcha      41     2.13
# 5      The INKEY List      40     2.08
# 6   Peter Thomas Roth      39     2.02
# 7            Caudalie      37     1.92
# 8      Paula's Choice      37     1.92
# 9            Shiseido      36     1.87

# %%
counts('tertiary_category', 'Product Type')
# Out:
#               Product Type  Counts  Percent
# 0              Face Serums     335    20.87
# 1             Moisturizers     329    20.50
# 2    Face Wash & Cleansers     182    11.34
# 3  Eye Creams & Treatments     134     8.35
# 4               Face Masks     104     6.48
# 5           Face Sunscreen      75     4.67
# 6                   Toners      61     3.80
# 7         Mists & Essences      55     3.43
# 8                Face Oils      53     3.30
# 9             Facial Peels      43     2.68
